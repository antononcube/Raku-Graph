# %% [markdown]
# # DOT format visualizations

# %% [markdown]
# ------
#
# ## Setup

# %%
use Graph;
use Graph::HexagonalGrid;

# %% [markdown]
# Here we set a collection of visualization variables:

# %%
my $title-color = 'Ivory';
my $stroke-color = 'SlateGray';
my $tooltip-color = 'LightBlue';
my $tooltip-background-color = 'none';
my $background = '#1F1F1F';
my $color-scheme = 'schemeTableau10';
my $edge-thickness = 3;
my $vertex-size = 6;
my $engine = 'neato';
my $mmd-theme = q:to/END/;
%%{
  init: {
    'theme': 'forest',
    'themeVariables': {
      'lineColor': 'Ivory'
    }
  }
}%%
END
my %force = collision => {iterations => 0, radius => 10},link => {distance => 180};
my %force2 = charge => {strength => -30, iterations => 4}, collision => {radius => 50, iterations => 4}, link => {distance => 30};
# Out:
# {charge => {iterations => 4, strength => -30}, collision => {iterations => 4, radius => 50}, link => {distance => 30}}

# %% [markdown]
# ### Dot

# %%
sub dot(Graph:D $g, *%opts) { $g.dot(:svg, |%opts) }
sub fdp(Graph:D $g, *%opts) { $g.dot(engine => 'fdp', :svg, |%opts) }
sub sfdp(Graph:D $g, *%opts) { $g.dot(engine => 'sfdp', :svg, |%opts) }
sub neato(Graph:D $g, *%opts) { $g.dot(engine => 'neato', :svg, |%opts) }
# Out:
# &neato

# %% [markdown]
# -----
#
# ## Direct

# %% [markdown]
# Here is a graph:

# %%
#% html
my $g = Graph::HexagonalGrid.new(3, 4, scale => 0.4)
# Out:
# Graph(vertexes => 38, edges => 49, directed => False)

# %% [markdown]
# Visualization using the Graphviz DOT language and CLI script `neato`:

# %%
#% html
$g.dot(
    background => '#1F1F1F',
    :node-labels,
    node-width => .3,
    node-height => .3,
    node-shape => 'hexagon',
    node-color => 'Ivory',
    node-penwidth => 1,
    node-fill-color => 'SlateBlue',
    node-font-size => 10,
    edge-thickness => 4,
    engine => 'neato', 
    graph-size => (8,8)
):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="576pt" height="346pt"
#  viewBox="0.00 0.00 576.00 346.19" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1.09002 1.09002) rotate(0) translate(4 313.6)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-313.6 524.43,-313.6 524.43,4 -4,4"/>
# <!-- 8 -->
# <g id="node1" class="node">
# <title>8</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-270 115.97,-280.8 105.17,-280.8 99.77,-270 105.17,-259.2 115.97,-259.2 121.37,-270"/>
# <text text-anchor="middle" x="110.57" y="-266.13" font-family="Times,serif" font-size="10.00" fill="White">8</text>
# </g>
# <!-- 12 -->
# <g id="node2" class="node">
# <title>12</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-298.8 165.85,-309.6 155.05,-309.6 149.65,-298.8 155.05,-288 165.85,-288 171.25,-298.8"/>
# <text text-anchor="middle" x="160.45" y="-294.93" font-family="Times,serif" font-size="10.00" fill="White">12</text>
# </g>
# <!-- 12&#45;&#45;8 -->
# <g id="edge1" class="edge">
# <title>12&#45;&#45;8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M151.76,-293.78C142.6,-288.5 128.27,-280.22 119.16,-274.96"/>
# </g>
# <!-- 16 -->
# <g id="node4" class="node">
# <title>16</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-270 215.73,-280.8 204.93,-280.8 199.53,-270 204.93,-259.2 215.73,-259.2 221.13,-270"/>
# <text text-anchor="middle" x="210.33" y="-266.13" font-family="Times,serif" font-size="10.00" fill="White">16</text>
# </g>
# <!-- 12&#45;&#45;16 -->
# <g id="edge11" class="edge">
# <title>12&#45;&#45;16</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M169.14,-293.78C178.29,-288.5 192.62,-280.22 201.74,-274.96"/>
# </g>
# <!-- 15 -->
# <g id="node3" class="node">
# <title>15</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-212.4 215.73,-223.2 204.93,-223.2 199.53,-212.4 204.93,-201.6 215.73,-201.6 221.13,-212.4"/>
# <text text-anchor="middle" x="210.33" y="-208.53" font-family="Times,serif" font-size="10.00" fill="White">15</text>
# </g>
# <!-- 15&#45;&#45;16 -->
# <g id="edge10" class="edge">
# <title>15&#45;&#45;16</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M210.33,-223.51C210.33,-233.71 210.33,-248.74 210.33,-258.93"/>
# </g>
# <!-- 19 -->
# <g id="node22" class="node">
# <title>19</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="271.02,-183.6 265.62,-194.4 254.82,-194.4 249.42,-183.6 254.82,-172.8 265.62,-172.8 271.02,-183.6"/>
# <text text-anchor="middle" x="260.22" y="-179.73" font-family="Times,serif" font-size="10.00" fill="White">19</text>
# </g>
# <!-- 15&#45;&#45;19 -->
# <g id="edge41" class="edge">
# <title>15&#45;&#45;19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M219.02,-207.38C228.18,-202.1 242.51,-193.82 251.63,-188.56"/>
# </g>
# <!-- 20 -->
# <g id="node19" class="node">
# <title>20</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="271.02,-298.8 265.62,-309.6 254.82,-309.6 249.42,-298.8 254.82,-288 265.62,-288 271.02,-298.8"/>
# <text text-anchor="middle" x="260.22" y="-294.93" font-family="Times,serif" font-size="10.00" fill="White">20</text>
# </g>
# <!-- 16&#45;&#45;20 -->
# <g id="edge9" class="edge">
# <title>16&#45;&#45;20</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M219.02,-275.02C228.18,-280.3 242.51,-288.58 251.63,-293.84"/>
# </g>
# <!-- 10 -->
# <g id="node5" class="node">
# <title>10</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-126 165.85,-136.8 155.05,-136.8 149.65,-126 155.05,-115.2 165.85,-115.2 171.25,-126"/>
# <text text-anchor="middle" x="160.45" y="-122.12" font-family="Times,serif" font-size="10.00" fill="White">10</text>
# </g>
# <!-- 14 -->
# <g id="node18" class="node">
# <title>14</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-97.2 215.73,-108 204.93,-108 199.53,-97.2 204.93,-86.4 215.73,-86.4 221.13,-97.2"/>
# <text text-anchor="middle" x="210.33" y="-93.32" font-family="Times,serif" font-size="10.00" fill="White">14</text>
# </g>
# <!-- 10&#45;&#45;14 -->
# <g id="edge46" class="edge">
# <title>10&#45;&#45;14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M169.14,-120.98C178.29,-115.7 192.62,-107.42 201.74,-102.16"/>
# </g>
# <!-- 6 -->
# <g id="node26" class="node">
# <title>6</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-97.2 115.97,-108 105.17,-108 99.77,-97.2 105.17,-86.4 115.97,-86.4 121.37,-97.2"/>
# <text text-anchor="middle" x="110.57" y="-93.32" font-family="Times,serif" font-size="10.00" fill="White">6</text>
# </g>
# <!-- 10&#45;&#45;6 -->
# <g id="edge17" class="edge">
# <title>10&#45;&#45;6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M151.76,-120.98C142.6,-115.7 128.27,-107.42 119.16,-102.16"/>
# </g>
# <!-- 11 -->
# <g id="node31" class="node">
# <title>11</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-183.6 165.85,-194.4 155.05,-194.4 149.65,-183.6 155.05,-172.8 165.85,-172.8 171.25,-183.6"/>
# <text text-anchor="middle" x="160.45" y="-179.73" font-family="Times,serif" font-size="10.00" fill="White">11</text>
# </g>
# <!-- 10&#45;&#45;11 -->
# <g id="edge48" class="edge">
# <title>10&#45;&#45;11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M160.45,-137.11C160.45,-147.31 160.45,-162.34 160.45,-172.53"/>
# </g>
# <!-- 23 -->
# <g id="node6" class="node">
# <title>23</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="320.9,-212.4 315.5,-223.2 304.7,-223.2 299.3,-212.4 304.7,-201.6 315.5,-201.6 320.9,-212.4"/>
# <text text-anchor="middle" x="310.1" y="-208.53" font-family="Times,serif" font-size="10.00" fill="White">23</text>
# </g>
# <!-- 27 -->
# <g id="node7" class="node">
# <title>27</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="370.78,-183.6 365.38,-194.4 354.58,-194.4 349.18,-183.6 354.58,-172.8 365.38,-172.8 370.78,-183.6"/>
# <text text-anchor="middle" x="359.98" y="-179.73" font-family="Times,serif" font-size="10.00" fill="White">27</text>
# </g>
# <!-- 23&#45;&#45;27 -->
# <g id="edge6" class="edge">
# <title>23&#45;&#45;27</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M318.79,-207.38C327.94,-202.1 342.27,-193.82 351.39,-188.56"/>
# </g>
# <!-- 24 -->
# <g id="node20" class="node">
# <title>24</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="320.9,-270 315.5,-280.8 304.7,-280.8 299.3,-270 304.7,-259.2 315.5,-259.2 320.9,-270"/>
# <text text-anchor="middle" x="310.1" y="-266.13" font-family="Times,serif" font-size="10.00" fill="White">24</text>
# </g>
# <!-- 23&#45;&#45;24 -->
# <g id="edge8" class="edge">
# <title>23&#45;&#45;24</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M310.1,-223.51C310.1,-233.71 310.1,-248.74 310.1,-258.93"/>
# </g>
# <!-- 31 -->
# <g id="node33" class="node">
# <title>31</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="420.66,-212.4 415.26,-223.2 404.46,-223.2 399.06,-212.4 404.46,-201.6 415.26,-201.6 420.66,-212.4"/>
# <text text-anchor="middle" x="409.86" y="-208.53" font-family="Times,serif" font-size="10.00" fill="White">31</text>
# </g>
# <!-- 27&#45;&#45;31 -->
# <g id="edge39" class="edge">
# <title>27&#45;&#45;31</title>
# <path fill="none" stroke="SteelBlue" stroke-width="4" d="M368.67,-188.62C377.83,-193.9 392.16,-202.18 401.28,-207.44"/>
# </g>
# <!-- 5 -->
# <g id="node8" class="node">
# <title>5</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-39.6 115.97,-50.4 105.17,-50.4 99.77,-39.6 105.17,-28.8 115.97,-28.8 121.37,-39.6"/>
# <text text-anchor="middle" x="110.57" y="-35.72" font-family="Times,serif" font-size="10.00" fill="White">5</text>
# </g>
# <!-- 9 -->
# <g id="node23" class="node">
# <title>9</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-10.8 165.85,-21.6 155.05,-21.6 149.65,-10.8 155.05,0 165.85,0 171.25,-10.8"/>
# <text text-anchor="middle" x="160.45" y="-6.93" font-family="Times,serif" font-size="10.00"

# %% [markdown]
# **Remark:** The adverb ":svg" specifies that the method `dot` to use Graphviz script specified with ":engine" via Raku's `run`.

# %% [markdown]
# -----
#
# # Using preamble

# %% [markdown]
# In some cases it is better to write the graph visualization specs directly using the DOT language.
# Here is an example:

# %%
#% html
my $preamble = q:to/END/;
label = "Hexagonal grid";
labelloc = "t";
fontsize = 20;
fontcolor="Gray";
bgcolor = "#1F1F1F";
node [style=filled, color = "Ivory", fillcolor = "SlateBlue", fontsize=12, fontcolor = "Ivory", shape = "hexagon", fixedsize=true, width=0.3, height=0.3];
edge [color = "SteelBlue", penwidth = 6]
END

$g.dot(:$preamble, engine => 'neato'):svg
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="528pt" height="348pt"
#  viewBox="0.00 0.00 528.43 348.10" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 344.1)">
# <polygon fill="#1f1f1f" stroke="none" points="-4,4 -4,-344.1 524.43,-344.1 524.43,4 -4,4"/>
# <text text-anchor="middle" x="260.22" y="-317.1" font-family="Times,serif" font-size="20.00" fill="Gray">Hexagonal grid</text>
# <!-- 8 -->
# <g id="node1" class="node">
# <title>8</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-270 115.97,-280.8 105.17,-280.8 99.77,-270 105.17,-259.2 115.97,-259.2 121.37,-270"/>
# <text text-anchor="middle" x="110.57" y="-265.73" font-family="Times,serif" font-size="12.00" fill="Ivory">8</text>
# </g>
# <!-- 12 -->
# <g id="node2" class="node">
# <title>12</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-298.8 165.85,-309.6 155.05,-309.6 149.65,-298.8 155.05,-288 165.85,-288 171.25,-298.8"/>
# <text text-anchor="middle" x="160.45" y="-294.53" font-family="Times,serif" font-size="12.00" fill="Ivory">12</text>
# </g>
# <!-- 12&#45;&#45;8 -->
# <g id="edge1" class="edge">
# <title>12&#45;&#45;8</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M151.76,-293.78C142.6,-288.5 128.27,-280.22 119.16,-274.96"/>
# </g>
# <!-- 16 -->
# <g id="node4" class="node">
# <title>16</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-270 215.73,-280.8 204.93,-280.8 199.53,-270 204.93,-259.2 215.73,-259.2 221.13,-270"/>
# <text text-anchor="middle" x="210.33" y="-265.73" font-family="Times,serif" font-size="12.00" fill="Ivory">16</text>
# </g>
# <!-- 12&#45;&#45;16 -->
# <g id="edge11" class="edge">
# <title>12&#45;&#45;16</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M169.14,-293.78C178.29,-288.5 192.62,-280.22 201.74,-274.96"/>
# </g>
# <!-- 15 -->
# <g id="node3" class="node">
# <title>15</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-212.4 215.73,-223.2 204.93,-223.2 199.53,-212.4 204.93,-201.6 215.73,-201.6 221.13,-212.4"/>
# <text text-anchor="middle" x="210.33" y="-208.13" font-family="Times,serif" font-size="12.00" fill="Ivory">15</text>
# </g>
# <!-- 15&#45;&#45;16 -->
# <g id="edge10" class="edge">
# <title>15&#45;&#45;16</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M210.33,-223.51C210.33,-233.71 210.33,-248.74 210.33,-258.93"/>
# </g>
# <!-- 19 -->
# <g id="node22" class="node">
# <title>19</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="271.02,-183.6 265.62,-194.4 254.82,-194.4 249.42,-183.6 254.82,-172.8 265.62,-172.8 271.02,-183.6"/>
# <text text-anchor="middle" x="260.22" y="-179.33" font-family="Times,serif" font-size="12.00" fill="Ivory">19</text>
# </g>
# <!-- 15&#45;&#45;19 -->
# <g id="edge41" class="edge">
# <title>15&#45;&#45;19</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M219.02,-207.38C228.18,-202.1 242.51,-193.82 251.63,-188.56"/>
# </g>
# <!-- 20 -->
# <g id="node19" class="node">
# <title>20</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="271.02,-298.8 265.62,-309.6 254.82,-309.6 249.42,-298.8 254.82,-288 265.62,-288 271.02,-298.8"/>
# <text text-anchor="middle" x="260.22" y="-294.53" font-family="Times,serif" font-size="12.00" fill="Ivory">20</text>
# </g>
# <!-- 16&#45;&#45;20 -->
# <g id="edge9" class="edge">
# <title>16&#45;&#45;20</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M219.02,-275.02C228.18,-280.3 242.51,-288.58 251.63,-293.84"/>
# </g>
# <!-- 10 -->
# <g id="node5" class="node">
# <title>10</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-126 165.85,-136.8 155.05,-136.8 149.65,-126 155.05,-115.2 165.85,-115.2 171.25,-126"/>
# <text text-anchor="middle" x="160.45" y="-121.72" font-family="Times,serif" font-size="12.00" fill="Ivory">10</text>
# </g>
# <!-- 14 -->
# <g id="node18" class="node">
# <title>14</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="221.13,-97.2 215.73,-108 204.93,-108 199.53,-97.2 204.93,-86.4 215.73,-86.4 221.13,-97.2"/>
# <text text-anchor="middle" x="210.33" y="-92.92" font-family="Times,serif" font-size="12.00" fill="Ivory">14</text>
# </g>
# <!-- 10&#45;&#45;14 -->
# <g id="edge46" class="edge">
# <title>10&#45;&#45;14</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M169.14,-120.98C178.29,-115.7 192.62,-107.42 201.74,-102.16"/>
# </g>
# <!-- 6 -->
# <g id="node26" class="node">
# <title>6</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-97.2 115.97,-108 105.17,-108 99.77,-97.2 105.17,-86.4 115.97,-86.4 121.37,-97.2"/>
# <text text-anchor="middle" x="110.57" y="-92.92" font-family="Times,serif" font-size="12.00" fill="Ivory">6</text>
# </g>
# <!-- 10&#45;&#45;6 -->
# <g id="edge17" class="edge">
# <title>10&#45;&#45;6</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M151.76,-120.98C142.6,-115.7 128.27,-107.42 119.16,-102.16"/>
# </g>
# <!-- 11 -->
# <g id="node31" class="node">
# <title>11</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-183.6 165.85,-194.4 155.05,-194.4 149.65,-183.6 155.05,-172.8 165.85,-172.8 171.25,-183.6"/>
# <text text-anchor="middle" x="160.45" y="-179.33" font-family="Times,serif" font-size="12.00" fill="Ivory">11</text>
# </g>
# <!-- 10&#45;&#45;11 -->
# <g id="edge48" class="edge">
# <title>10&#45;&#45;11</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M160.45,-137.11C160.45,-147.31 160.45,-162.34 160.45,-172.53"/>
# </g>
# <!-- 23 -->
# <g id="node6" class="node">
# <title>23</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="320.9,-212.4 315.5,-223.2 304.7,-223.2 299.3,-212.4 304.7,-201.6 315.5,-201.6 320.9,-212.4"/>
# <text text-anchor="middle" x="310.1" y="-208.13" font-family="Times,serif" font-size="12.00" fill="Ivory">23</text>
# </g>
# <!-- 27 -->
# <g id="node7" class="node">
# <title>27</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="370.78,-183.6 365.38,-194.4 354.58,-194.4 349.18,-183.6 354.58,-172.8 365.38,-172.8 370.78,-183.6"/>
# <text text-anchor="middle" x="359.98" y="-179.33" font-family="Times,serif" font-size="12.00" fill="Ivory">27</text>
# </g>
# <!-- 23&#45;&#45;27 -->
# <g id="edge6" class="edge">
# <title>23&#45;&#45;27</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M318.79,-207.38C327.94,-202.1 342.27,-193.82 351.39,-188.56"/>
# </g>
# <!-- 24 -->
# <g id="node20" class="node">
# <title>24</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="320.9,-270 315.5,-280.8 304.7,-280.8 299.3,-270 304.7,-259.2 315.5,-259.2 320.9,-270"/>
# <text text-anchor="middle" x="310.1" y="-265.73" font-family="Times,serif" font-size="12.00" fill="Ivory">24</text>
# </g>
# <!-- 23&#45;&#45;24 -->
# <g id="edge8" class="edge">
# <title>23&#45;&#45;24</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M310.1,-223.51C310.1,-233.71 310.1,-248.74 310.1,-258.93"/>
# </g>
# <!-- 31 -->
# <g id="node33" class="node">
# <title>31</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="420.66,-212.4 415.26,-223.2 404.46,-223.2 399.06,-212.4 404.46,-201.6 415.26,-201.6 420.66,-212.4"/>
# <text text-anchor="middle" x="409.86" y="-208.13" font-family="Times,serif" font-size="12.00" fill="Ivory">31</text>
# </g>
# <!-- 27&#45;&#45;31 -->
# <g id="edge39" class="edge">
# <title>27&#45;&#45;31</title>
# <path fill="none" stroke="SteelBlue" stroke-width="6" d="M368.67,-188.62C377.83,-193.9 392.16,-202.18 401.28,-207.44"/>
# </g>
# <!-- 5 -->
# <g id="node8" class="node">
# <title>5</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="121.37,-39.6 115.97,-50.4 105.17,-50.4 99.77,-39.6 105.17,-28.8 115.97,-28.8 121.37,-39.6"/>
# <text text-anchor="middle" x="110.57" y="-35.32" font-family="Times,serif" font-size="12.00" fill="Ivory">5</text>
# </g>
# <!-- 9 -->
# <g id="node23" class="node">
# <title>9</title>
# <polygon fill="SlateBlue" stroke="Ivory" points="171.25,-10.8 165.85,-21.6 155.05,-21.6 149.65,-10.8 155.05,0 16

# %% [markdown]
# -----
#
# ## Redirection

# %% [markdown]
# In this section is shown how to generate the graph images using access to the Graphviz CLI scripts. (Like `dot`, `neato`, etc.)

# %% [markdown]
# Get the DOT spec for a graph:

# %%
my $spec = $g.dot()
# Out:
# graph {
# "8" [pos="-0.692820323028,2!"];
# "12" [pos="0,2.4!"];
# "15" [pos="0.692820323028,1.2!"];
# "16" [pos="0.692820323028,2!"];
# "10" [pos="0,0!"];
# "23" [pos="2.078460969083,1.2!"];
# "27" [pos="2.77128129211,0.7999999999999999!"];
# "5" [pos="-0.692820323028,-1.2!"];
# "1" [pos="-2.078460969083,-0.39999999999999997!"];
# "37" [pos="4.849742261193,2!"];
# "0" [pos="-2.078460969083,-1.2!"];
# "7" [pos="-0.692820323028,1.2!"];
# "3" [pos="-1.385640646055,0!"];
# "18" [pos="1.385640646055,0!"];
# "13" [pos="0.692820323028,-1.2!"];
# "4" [pos="-1.385640646055,0.7999999999999999!"];
# "34" [pos="4.1569219381649996,0.7999999999999999!"];
# "14" [pos="0.692820323028,-0.39999999999999997!"];
# "20" [pos="1.385640646055,2.4!"];
# "24" [pos="2.078460969083,2!"];
# "33" [pos="4.1569219381649996,0!"];
# "19" [pos="1.385640646055,0.7999999999999999!"];
# "9" [pos="0,-1.5999999999999999!"];
# "2" [pos="-1.385640646055,-1.5999999999999999!"];
# "22" [pos="2.078460969083,-0.39999999999999997!"];
# "6" [pos="-0.692820323028,-0.39999999999999997!"];
# "21" [pos="2.078460969083,-1.2!"];
# "25" [pos="2.77128129211,-1.5999999999999999!"];
# "17" [pos="1.385640646055,-1.5999999999999999!"];
# "35" [pos="4.1569219381649996,2.4!"];
# "11" [pos="0,0.7999999999999999!"];
# "26" [pos="2.77128129211,0!"];
# "31" [pos="3.464101615138,1.2!"];
# "32" [pos="3.464101615138,2!"];
# "28" [pos="2.77128129211,2.4!"];
# "36" [pos="4.849742261193,1.2!"];
# "29" [pos="3.464101615138,-1.2!"];
# "30" [pos="3.464101615138,-0.39999999999999997!"]
# "12" -- "8"
# "7" -- "8"
# "26" -- "30"
# "30" -- "33"
# "29" -- "30"
# "23" -- "27"
# "19" -- "23"
# "23" -- "24"
# "16" -- "20"
# "15" -- "16"
# "12" -- "16"
# "2" -- "5"
# "0" -- "2"
# "28" -- "32"
# "32" -- "35"
# "31" -- "32"
# "10" -- "6"
# "3" -- "6"
# "5" -- "6"
# "13" -- "9"
# "5" -- "9"
# "11" -- "7"
# "4" -- "7"
# "18" -- "22"
# "14" -- "18"
# "18" -- "19"
# "20" -- "24"
# "24" -- "28"
# "1" -- "3"
# "0" -- "1"
# "31" -- "34"
# "34" -- "36"
# "33" -- "34"
# "3" -- "4"
# "21" -- "25"
# "25" -- "29"
# "13" -- "17"
# "17" -- "21"
# "27" -- "31"
# "26" -- "27"
# "15" -- "19"
# "11" -- "15"
# "35" -- "37"
# "36" -- "37"
# "13" -- "14"
# "10" -- "14"
# "21" -- "22"
# "10" -- "11"
# "22" -- "26"
# }

# %% [markdown]
# Below the following steps are done:
#
# 1. Export DOT spec into a file
# 2. Generate the SVG code and safe to a file
# 3. Import and show into an HTML magic cell

# %%
spurt('./example-spec.dot', $spec);
shell "neato ./example-spec.dot  -Tsvg > example-spec.svg";
# Out:
# Proc.new(in => IO::Pipe, out => IO::Pipe, err => IO::Pipe, os-error => Str, exitcode => 0, signal => 0, pid => 18409, command => ("neato ./example-spec.dot  -Tsvg > example-spec.svg",))

# %%
#% html
slurp('./example-spec.svg')
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 11.0.0 (20240428.1522)
#  -->
# <!-- Pages: 1 -->
# <svg width="561pt" height="332pt"
#  viewBox="0.00 0.00 560.83 332.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 328)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-328 556.83,-328 556.83,4 -4,4"/>
# <!-- 8 -->
# <g id="node1" class="node">
# <title>8</title>
# <ellipse fill="none" stroke="black" cx="126.77" cy="-277.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="126.77" y="-272.15" font-family="Times,serif" font-size="14.00">8</text>
# </g>
# <!-- 12 -->
# <g id="node2" class="node">
# <title>12</title>
# <ellipse fill="none" stroke="black" cx="176.65" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="176.65" y="-300.95" font-family="Times,serif" font-size="14.00">12</text>
# </g>
# <!-- 12&#45;&#45;8 -->
# <g id="edge1" class="edge">
# <title>12&#45;&#45;8</title>
# <path fill="none" stroke="black" d="M155.78,-293.95C153.01,-292.35 150.16,-290.71 147.39,-289.11"/>
# </g>
# <!-- 16 -->
# <g id="node4" class="node">
# <title>16</title>
# <ellipse fill="none" stroke="black" cx="226.53" cy="-277.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="226.53" y="-272.15" font-family="Times,serif" font-size="14.00">16</text>
# </g>
# <!-- 12&#45;&#45;16 -->
# <g id="edge11" class="edge">
# <title>12&#45;&#45;16</title>
# <path fill="none" stroke="black" d="M197.52,-293.95C200.29,-292.35 203.14,-290.71 205.91,-289.11"/>
# </g>
# <!-- 15 -->
# <g id="node3" class="node">
# <title>15</title>
# <ellipse fill="none" stroke="black" cx="226.53" cy="-219.6" rx="27" ry="18"/>
# <text text-anchor="middle" x="226.53" y="-214.55" font-family="Times,serif" font-size="14.00">15</text>
# </g>
# <!-- 15&#45;&#45;16 -->
# <g id="edge10" class="edge">
# <title>15&#45;&#45;16</title>
# <path fill="none" stroke="black" d="M226.53,-237.83C226.53,-244.55 226.53,-252.17 226.53,-258.9"/>
# </g>
# <!-- 19 -->
# <g id="node22" class="node">
# <title>19</title>
# <ellipse fill="none" stroke="black" cx="276.42" cy="-190.8" rx="27" ry="18"/>
# <text text-anchor="middle" x="276.42" y="-185.75" font-family="Times,serif" font-size="14.00">19</text>
# </g>
# <!-- 15&#45;&#45;19 -->
# <g id="edge41" class="edge">
# <title>15&#45;&#45;19</title>
# <path fill="none" stroke="black" d="M247.4,-207.55C250.17,-205.95 253.02,-204.31 255.79,-202.71"/>
# </g>
# <!-- 20 -->
# <g id="node19" class="node">
# <title>20</title>
# <ellipse fill="none" stroke="black" cx="276.42" cy="-306" rx="27" ry="18"/>
# <text text-anchor="middle" x="276.42" y="-300.95" font-family="Times,serif" font-size="14.00">20</text>
# </g>
# <!-- 16&#45;&#45;20 -->
# <g id="edge9" class="edge">
# <title>16&#45;&#45;20</title>
# <path fill="none" stroke="black" d="M247.4,-289.25C250.17,-290.85 253.02,-292.49 255.79,-294.09"/>
# </g>
# <!-- 10 -->
# <g id="node5" class="node">
# <title>10</title>
# <ellipse fill="none" stroke="black" cx="176.65" cy="-133.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="176.65" y="-128.15" font-family="Times,serif" font-size="14.00">10</text>
# </g>
# <!-- 14 -->
# <g id="node18" class="node">
# <title>14</title>
# <ellipse fill="none" stroke="black" cx="226.53" cy="-104.4" rx="27" ry="18"/>
# <text text-anchor="middle" x="226.53" y="-99.35" font-family="Times,serif" font-size="14.00">14</text>
# </g>
# <!-- 10&#45;&#45;14 -->
# <g id="edge46" class="edge">
# <title>10&#45;&#45;14</title>
# <path fill="none" stroke="black" d="M197.52,-121.15C200.29,-119.55 203.14,-117.91 205.91,-116.31"/>
# </g>
# <!-- 6 -->
# <g id="node26" class="node">
# <title>6</title>
# <ellipse fill="none" stroke="black" cx="126.77" cy="-104.4" rx="27" ry="18"/>
# <text text-anchor="middle" x="126.77" y="-99.35" font-family="Times,serif" font-size="14.00">6</text>
# </g>
# <!-- 10&#45;&#45;6 -->
# <g id="edge17" class="edge">
# <title>10&#45;&#45;6</title>
# <path fill="none" stroke="black" d="M155.78,-121.15C153.01,-119.55 150.16,-117.91 147.39,-116.31"/>
# </g>
# <!-- 11 -->
# <g id="node31" class="node">
# <title>11</title>
# <ellipse fill="none" stroke="black" cx="176.65" cy="-190.8" rx="27" ry="18"/>
# <text text-anchor="middle" x="176.65" y="-185.75" font-family="Times,serif" font-size="14.00">11</text>
# </g>
# <!-- 10&#45;&#45;11 -->
# <g id="edge48" class="edge">
# <title>10&#45;&#45;11</title>
# <path fill="none" stroke="black" d="M176.65,-151.42C176.65,-158.15 176.65,-165.77 176.65,-172.5"/>
# </g>
# <!-- 23 -->
# <g id="node6" class="node">
# <title>23</title>
# <ellipse fill="none" stroke="black" cx="326.3" cy="-219.6" rx="27" ry="18"/>
# <text text-anchor="middle" x="326.3" y="-214.55" font-family="Times,serif" font-size="14.00">23</text>
# </g>
# <!-- 27 -->
# <g id="node7" class="node">
# <title>27</title>
# <ellipse fill="none" stroke="black" cx="376.18" cy="-190.8" rx="27" ry="18"/>
# <text text-anchor="middle" x="376.18" y="-185.75" font-family="Times,serif" font-size="14.00">27</text>
# </g>
# <!-- 23&#45;&#45;27 -->
# <g id="edge6" class="edge">
# <title>23&#45;&#45;27</title>
# <path fill="none" stroke="black" d="M347.16,-207.55C349.94,-205.95 352.79,-204.31 355.56,-202.71"/>
# </g>
# <!-- 24 -->
# <g id="node20" class="node">
# <title>24</title>
# <ellipse fill="none" stroke="black" cx="326.3" cy="-277.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="326.3" y="-272.15" font-family="Times,serif" font-size="14.00">24</text>
# </g>
# <!-- 23&#45;&#45;24 -->
# <g id="edge8" class="edge">
# <title>23&#45;&#45;24</title>
# <path fill="none" stroke="black" d="M326.3,-237.83C326.3,-244.55 326.3,-252.17 326.3,-258.9"/>
# </g>
# <!-- 31 -->
# <g id="node33" class="node">
# <title>31</title>
# <ellipse fill="none" stroke="black" cx="426.06" cy="-219.6" rx="27" ry="18"/>
# <text text-anchor="middle" x="426.06" y="-214.55" font-family="Times,serif" font-size="14.00">31</text>
# </g>
# <!-- 27&#45;&#45;31 -->
# <g id="edge39" class="edge">
# <title>27&#45;&#45;31</title>
# <path fill="none" stroke="black" d="M397.05,-202.85C399.82,-204.45 402.67,-206.09 405.44,-207.69"/>
# </g>
# <!-- 5 -->
# <g id="node8" class="node">
# <title>5</title>
# <ellipse fill="none" stroke="black" cx="126.77" cy="-46.8" rx="27" ry="18"/>
# <text text-anchor="middle" x="126.77" y="-41.75" font-family="Times,serif" font-size="14.00">5</text>
# </g>
# <!-- 9 -->
# <g id="node23" class="node">
# <title>9</title>
# <ellipse fill="none" stroke="black" cx="176.65" cy="-18" rx="27" ry="18"/>
# <text text-anchor="middle" x="176.65" y="-12.95" font-family="Times,serif" font-size="14.00">9</text>
# </g>
# <!-- 5&#45;&#45;9 -->
# <g id="edge21" class="edge">
# <title>5&#45;&#45;9</title>
# <path fill="none" stroke="black" d="M147.63,-34.75C150.41,-33.15 153.25,-31.51 156.03,-29.91"/>
# </g>
# <!-- 5&#45;&#45;6 -->
# <g id="edge19" class="edge">
# <title>5&#45;&#45;6</title>
# <path fill="none" stroke="black" d="M126.77,-65.02C126.77,-71.75 126.77,-79.37 126.77,-86.1"/>
# </g>
# <!-- 1 -->
# <g id="node9" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="27" cy="-104.4" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-99.35" font-family="Times,serif" font-size="14.00">1</text>
# </g>
# <!-- 3 -->
# <g id="node13" class="node">
# <title>3</title>
# <ellipse fill="none" stroke="black" cx="76.88" cy="-133.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="76.88" y="-128.15" font-family="Times,serif" font-size="14.00">3</text>
# </g>
# <!-- 1&#45;&#45;3 -->
# <g id="edge29" class="edge">
# <title>1&#45;&#45;3</title>
# <path fill="none" stroke="black" d="M47.87,-116.45C50.64,-118.05 53.49,-119.69 56.26,-121.29"/>
# </g>
# <!-- 37 -->
# <g id="node10" class="node">
# <title>37</title>
# <ellipse fill="none" stroke="black" cx="525.83" cy="-277.2" rx="27" ry="18"/>
# <text text-anchor="middle" x="525.83" y="-272.15" font-family="Times,serif" font-size="14.00">37</text>
# </g>
# <!-- 0 -->
# <g id="node11" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="27" cy="-46.8" rx="27" ry="18"/>
# <text text-anchor="middle" x="27" y="-41.75" font-family="Times,serif" font-size="14.00">0</text>
# </g>
# <!-- 0&
